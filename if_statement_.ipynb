# %% [markdown]
# <a href="https://colab.research.google.com/github/saieadara/python/blob/main/if_statement_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 3
b = 5
print (a & b)
# Out:
# 1

# %%
#if statement one way

# %%
num = 3
if num > 0:
  print ("it is a positive number", num)
# Out:
# it is a positive number 3

# %%
num = 4
if num > 1:
  print("it is a real number", num)
# Out:
# it is a real number 4

# %%
num = int(input("Enter a number"))
if num > 0:
   print("it is a real number:", num)
# Out:
# Enter a number2
# it is a real number: 2

# %%
num = int(input("Enter a number:"))
if (num % 2) == 0:
  print("it is a even number")
else:
    print("it is an odd number:")
# Out:
# Enter a number:4
# it is a even number

# %%
#student grades if elif

# %%
grade = int(input("Enter Your Marks: "))
if grade >= 90:
    print("Your Grade is A+")
elif grade >= 80:
    print("Your Grade is A")
elif grade >= 70:
    print("Your Grade is B+")
else:
    print("Sorry You Failed")
# Out:
# Enter Your Marks: 45
# Sorry You Failed

# %%
grade = int(input("Enter your marks: "))
if grade >= 90:
  print("your grade is A")
elif grade >= 80:
  print("your grade is B")
elif grade >= 70:
  print("your grade is c")
elif grade >= 60:
  print("your grade is d")
else:
  print("sorry you failed")
# Out:
# Enter your marks: 60
# your grade is d
